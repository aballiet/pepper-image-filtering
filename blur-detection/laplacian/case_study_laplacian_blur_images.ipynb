# %% [markdown]
# # Detect blurred images and face in ROSbag
#
# **This project aims at reducing bandwidth taken by the image ROS topic of the pepper robot**
#
# We want to filter out, blurred images to reduce amount of data we have to deal with inside the pipeline

# %%
# import the necessary packages
from imutils    import paths
from matplotlib import pyplot as plt
from tools      import check_if_blurred # import custom functions
import cv2
import face_recognition
import os
import shutil

# %%
def variance_of_laplacian(image):
    # compute the Laplacian of the image and then return the focus
    # measure, which is simply the variance of the Laplacian
    return cv2.Laplacian(image, cv2.CV_64F).var()

# %%
threshold  = 2000.0  # seems to be the best threshold for our dataset

base_path ='../../dataset'

image_path   = base_path + '/original'
dest_blurred = base_path + '/blurred'
dest_sharp   = base_path + '/sharp'

# %%
if not os.path.exists(dest_blurred):
    os.makedirs(dest_blurred)
    
if not os.path.exists(dest_sharp):
    os.makedirs(dest_sharp)

# %%
check_if_blurred(base_path, threshold, copy=True, logging=True)
# Out:
# copy ../../dataset/original\frame000000.png
# copy ../../dataset/original\frame000001.png
# copy ../../dataset/original\frame000005.png
# copy ../../dataset/original\frame000006.png
# copy ../../dataset/original\frame000007.png
# copy ../../dataset/original\frame000010.png
# copy ../../dataset/original\frame000011.png
# copy ../../dataset/original\frame000012.png
# copy ../../dataset/original\frame000013.png
# copy ../../dataset/original\frame000014.png
# copy ../../dataset/original\frame000015.png
# copy ../../dataset/original\frame000016.png
# copy ../../dataset/original\frame000017.png
# copy ../../dataset/original\frame000029.png
# copy ../../dataset/original\frame000030.png
# copy ../../dataset/original\frame000031.png
# copy ../../dataset/original\frame000032.png
# copy ../../dataset/original\frame000033.png
# copy ../../dataset/original\frame000034.png
# copy ../../dataset/original\frame000035.png
# copy ../../dataset/original\frame000036.png
# copy ../../dataset/original\frame000037.png
# copy ../../dataset/original\frame000038.png
# copy ../../dataset/original\frame000039.png
# copy ../../dataset/original\frame000040.png
# copy ../../dataset/original\frame000041.png
# copy ../../dataset/original\frame000042.png
# copy ../../dataset/original\frame000043.png
# copy ../../dataset/original\frame000044.png
# copy ../../dataset/original\frame000045.png
# copy ../../dataset/original\frame000046.png
# copy ../../dataset/original\frame000047.png
# copy ../../dataset/original\frame000048.png
# copy ../../dataset/original\frame000049.png
# copy ../../dataset/original\frame000050.png
# copy ../../dataset/original\frame000051.png
# copy ../../dataset/original\frame000052.png
# copy ../../dataset/original\frame000053.png
# copy ../../dataset/original\frame000054.png
# copy ../../dataset/original\frame000055.png
# copy ../../dataset/original\frame000056.png
# copy ../../dataset/original\frame000057.png
# copy ../../dataset/original\frame000058.png
# copy ../../dataset/original\frame000059.png
# copy ../../dataset/original\frame000060.png
# copy ../../dataset/original\frame000061.png
# copy ../../dataset/original\frame000062.png
# copy ../../dataset/original\frame000063.png
# copy ../../dataset/original\frame000064.png
# copy ../../dataset/original\frame000065.png
# copy ../../dataset/original\frame000066.png
# copy ../../dataset/original\frame000070.png
# copy ../../dataset/original\frame000071.png
# copy ../../dataset/original\frame000072.png
# copy ../../dataset/original\frame000073.png
# copy ../../dataset/original\frame000074.png
# copy ../../dataset/original\frame000075.png
# copy ../../dataset/original\frame000076.png
# copy ../../dataset/original\frame000077.png
# copy ../../dataset/original\frame000078.png
# copy ../../dataset/original\frame000079.png
# copy ../../dataset/original\frame000080.png
# copy ../../dataset/original\frame000081.png
# copy ../../dataset/original\frame000082.png
# copy ../../dataset/original\frame000083.png
# copy ../../dataset/original\frame000084.png
# copy ../../dataset/original\frame000085.png
# copy ../../dataset/original\frame000086.png
# copy ../../dataset/original\frame000087.png
# copy ../../dataset/original\frame000088.png
# copy ../../dataset/original\frame000089.png
# copy ../../dataset/original\frame000090.png
# copy ../../dataset/original\frame000091.png
# copy ../../dataset/original\frame000092.png
# copy ../../dataset/original\frame000093.png
# copy ../../dataset/original\frame000094.png
# copy ../../dataset/original\frame000095.png
# copy ../../dataset/original\frame000096.png
# copy ../../dataset/original\frame000097.png
# copy ../../dataset/original\frame000098.png
# copy ../../dataset/original\frame000099.png
# copy ../../dataset/original\frame000100.png
# copy ../../dataset/original\frame000101.png
# copy ../../dataset/original\frame000102.png
# copy ../../dataset/original\frame000103.png
# copy ../../dataset/original\frame000104.png
# copy ../../dataset/original\frame000105.png
# copy ../../dataset/original\frame000106.png
# copy ../../dataset/original\frame000107.png
# copy ../../dataset/original\frame000108.png
# copy ../../dataset/original\frame000109.png
# copy ../../dataset/original\frame000110.png
# copy ../../dataset/original\frame000111.png
# copy ../../dataset/original\frame000112.png
# copy ../../dataset/original\frame000113.png
# copy ../../dataset/original\frame000114.png
# copy ../../dataset/original\frame000115.png
# copy ../../dataset/original\frame000116.png
# copy ../../dataset/original\frame000117.png
# copy ../../dataset/original\frame000118.png
# copy ../../dataset/original\frame000119.png
# copy ../../dataset/original\frame000120.png
# copy ../../dataset/original\frame000121.png
# copy ../../dataset/original\frame000122.png
# copy ../../dataset/original\frame000123.png
# copy ../../dataset/original\frame000124.png
# copy ../../dataset/original\frame000125.png
# copy ../../dataset/original\frame000126.png
# copy ../../dataset/original\frame000127.png
# copy ../../dataset/original\frame000128.png
# copy ../../dataset/original\frame000129.png
# copy ../../dataset/original\frame000130.png
# copy ../../dataset/original\frame000131.png
# copy ../../dataset/original\frame000132.png
# copy ../../dataset/original\frame000133.png
# copy ../../dataset/original\frame000134.png
# copy ../../dataset/original\frame000135.png
# copy ../../dataset/original\frame000136.png
# copy ../../dataset/original\frame000137.png
# copy ../../dataset/original\frame000138.png
# copy ../../dataset/original\frame000139.png
# copy ../../dataset/original\frame000140.png
# copy ../../dataset/original\frame000141.png
# copy ../../dataset/original\frame000142.png
# copy ../../dataset/original\frame000143.png
# copy ../../dataset/original\frame000144.png
# copy ../../dataset/original\frame000145.png
# copy ../../dataset/original\frame000146.png
# copy ../../dataset/original\frame000147.png
# copy ../../dataset/original\frame000148.png
# copy ../../dataset/original\frame000149.png
# copy ../../dataset/original\frame000150.png
# copy ../../dataset/original\frame000151.png
# copy ../../dataset/original\frame000152.png
# copy ../../dataset/original\frame000153.png
# copy ../../dataset/original\frame000154.png
# copy ../../dataset/original\frame000155.png
# copy ../../dataset/original\frame000156.png
# copy ../../dataset/original\frame000157.png
# copy ../../dataset/original\frame000158.png
# copy ../../dataset/original\frame000159.png
# copy ../../dataset/original\frame000160.png
# copy ../../dataset/original\frame000161.png
# copy ../../dataset/original\frame000162.png
# copy ../../dataset/original\frame000163.png
# copy ../../dataset/original\frame000164.png
# copy ../../dataset/original\frame000165.png
# copy ../../dataset/original\frame000176.png
# copy ../../dataset/original\frame000177.png
# copy ../../dataset/original\frame000183.png
# copy ../../dataset/original\frame000186.png
# copy ../../dataset/original\frame000193.png
# copy ../../dataset/original\frame000194.png
# copy ../../dataset/original\frame000195.png
# copy ../../dataset/original\frame000196.png
# copy ../../dataset/original\frame000197.png
# copy ../../dataset/original\frame000198.png
# copy ../../dataset/original\frame000199.png
# copy ../../dataset/original\frame000200.png
# copy ../../dataset/original\frame000204.png
# copy ../../dataset/original\frame000205.png
# copy ../../dataset/original\frame000206.png
# copy ../../dataset/original\frame000207.png
# copy ../../dataset/original\frame000208.png
# copy ../../dataset/original\frame000209.png
# copy ../../dataset/original\frame000210.png
# copy ../../dataset/original\frame000211.png
# copy ../../dataset/original\frame000212.png
# copy ../../dataset/original\frame000213.png
# copy ../../dataset/original\frame000214.png
# copy ../../dataset/original\frame000215.png
# copy ../../dataset/original\frame000216.png
# copy ../../dataset/original\frame000217.png
# copy ../../dataset/original\frame000218.png
# copy ../../dataset/original\frame000219.png
# copy ../../dataset/original\frame000220.png
# copy ../../dataset/original\frame000221.png
# copy ../../dataset/original\frame000222.png
# copy ../../dataset/original\frame000223.png
# copy ../../dataset/original\frame000224.png
# copy ../../dataset/original\frame000225.png
# copy ../../dataset/original\frame000226.png
# copy ../../dataset/original\frame000227.png
# copy ../../dataset/original\frame000228.png
# copy ../../dataset/original\frame000229.png
# copy ../../dataset/original\frame000230.png
# copy ../../dataset/original\frame000231.png
# copy ../../dataset/original\frame000232.png
# copy ../../dataset/original\frame000233.png
# copy ../../dataset/original\frame000234.png
# copy ../../dataset/original\frame000235.png
# copy ../../dataset/original\frame000236.png
# copy ../../dataset/original\frame000237.png
# copy ../../dataset/original\frame000238.png
# copy ../../dataset/original\frame000239.png
# copy ../../dataset/original\frame000240.png
# copy ../../dataset/original\frame000241.png
# copy ../../dataset/original\frame000242.png
# copy ../../dataset/original\frame000243.png
# copy ../../dataset/original\frame000244.png
# copy ../../dataset/original\frame000245.png
# copy ../../dataset/original\frame000246.png
# copy ../../dataset/original\frame000247.png
# copy ../../dataset/original\frame000248.png
# copy ../../dataset/original\frame000249.png
# copy ../../dataset/original\frame000250.png
# copy ../../dataset/original\frame000251.png
# copy ../../dataset/original\frame000252.png
# copy ../../dataset/original\frame000253.png
# copy ../../dataset/original\frame000254.png
# copy ../../dataset/original\frame000255.png
# copy ../../dataset/original\frame000256.png
# copy ../../dataset/original\frame000257.png
# copy ../../dataset/original\frame000258.png
# copy ../../dataset/original\frame000259.png
# copy ../../dataset/original\frame000260.png
# copy ../../dataset/original\frame000261.png
# copy ../../dataset/original\frame000262.png
# copy ../../dataset/original\frame000263.png
# copy ../../dataset/original\frame000264.png
# copy ../../dataset/original\frame000265.png
# copy ../../dataset/original\frame000266.png
# copy ../../dataset/original\frame000267.png
# copy ../../dataset/original\frame000268.png
# copy ../../dataset/original\frame000269.png
# copy ../../dataset/original\frame000270.png
# copy ../../dataset/original\frame000271.png
# copy ../../dataset/original\frame000272.png
# copy ../../dataset/original\frame000273.png
# copy ../../dataset/original\frame000274.png
# copy ../../dataset/original\frame000275.png
# copy ../../dataset/original\frame000276.png
# copy ../../dataset/original\frame000277.png
# copy ../../dataset/original\frame000278.png
# copy ../../dataset/original\frame000279.png
# copy ../../dataset/original\frame000280.png
# copy ../../dataset/original\frame000281.png
# copy ../../dataset/original\frame000282.png
# copy ../../dataset/original\frame000283.png
# copy ../../dataset/original\frame000284.png
# copy ../../dataset/original\frame000285.png
# copy ../../dataset/original\frame000286.png
# copy ../../dataset/original\frame000287.png
# copy ../../dataset/original\frame000288.png
# copy ../../dataset/original\frame000289.png
# copy ../../dataset/original\frame000290.png
# copy ../../dataset/original\frame000291.png
# copy ../../dataset/original\frame000292.png
# copy ../../dataset/original\frame000293.png
# copy ../../dataset/original\frame000294.png
# copy ../../dataset/original\frame000295.png
# copy ../../dataset/original\frame000296.png
# copy ../../dataset/original\frame000297.png
# copy ../../dataset/original\frame000298.png
# copy ../../dataset/original\frame000309.png
# copy ../../dataset/original\frame000310.png
# copy ../../dataset/original\frame000311.png
# copy ../../dataset/original\frame000312.png
# copy ../../dataset/original\frame000318.png
# copy ../../dataset/original\frame000319.png
# copy ../../dataset/original\frame000320.png
# copy ../../dataset/original\frame000321.png
# copy ../../dataset/original\frame000326.png
# copy ../../dataset/original\frame000331.png
# copy ../../dataset/original\frame000332.png
# copy ../../dataset/original\frame000333.png
# copy ../../dataset/original\frame000334.png
# copy ../../dataset/original\frame000335.png
# copy ../../dataset/original\frame000336.png
# copy ../../dataset/original\frame000337.png
# copy ../../dataset/original\frame000338.png
# copy ../../dataset/original\frame000339.png
# copy ../../dataset/original\frame000341.png
# copy ../../dataset/original\frame000349.png
# copy ../../dataset/original\frame000350.png
# copy ../../dataset/original\frame000351.png
# copy ../../dataset/original\frame000352.png
# copy ../../dataset/original\frame000353.png
# copy ../../dataset/original\frame000354.png
# copy ../../dataset/original\frame000373.png
# copy ../../dataset/original\frame000374.png
# copy ../../dataset/original\frame000412.png
# copy ../../dataset/original\frame000415.png
# copy ../../dataset/original\frame000416.png
# copy ../../dataset/original\frame000417.png
# copy ../../dataset/original\frame000418.png
# copy ../../dataset/original\frame000419.png
# copy ../../dataset/original\frame000420.png
# copy ../../dataset/original\frame000421.png
# copy ../../dataset/original\frame000422.png
# copy ../../dataset/original\frame000423.png
# copy ../../dataset/original\frame000424.png
# copy ../../dataset/original\frame000433.png
# copy ../../dataset/original\frame000434.png
# copy ../../dataset/original\frame000435.png
# copy ../../dataset/original\frame000436.png
# copy ../../dataset/original\frame000442.png
# copy ../../dataset/original\frame000443.png
# copy ../../dataset/original\frame000444.png
# copy ../../dataset/original\frame000445.png
# copy ../../dataset/original\frame000446.png
# copy ../../dataset/original\frame000447.png
# copy ../../dataset/original\frame000448.png
# copy ../../dataset/original\frame000449.png
# copy ../../dataset/original\frame000450.png
# copy ../../dataset/original\frame000451.png
# copy ../../dataset/original\frame000452.png
# copy ../../dataset/original\frame000453.png
# copy ../../dataset/original\frame000454.png
# copy ../../dataset/original\frame000455.png
# copy ../../dataset/original\frame000456.png
# copy ../../dataset/original\frame000457.png
# copy ../../dataset/original\frame000458.png
# copy ../../dataset/original\frame000459.png
# copy ../../dataset/original\frame000460.png
# copy ../../dataset/original\frame000461.png
# copy ../../dataset/original\frame000462.png
# copy ../../dataset/original\frame000463.png
# copy ../../dataset/original\frame000464.png
# copy ../../dataset/original\frame000465.png
# copy ../../dataset/original\frame000466.png
# copy ../../dataset/original\frame000467.png
# copy ../../dataset/original\frame000468.png
# copy ../../dataset/original\frame000469.png
# copy ../../dataset/original\frame000470.png
# copy ../../dataset/original\frame000471.png
# copy ../../dataset/original\frame000472.png
# copy ../../dataset/original\frame000473.png
# copy ../../dataset/original\frame000474.png
# copy ../../dataset/original\frame000475.png
# copy ../../dataset/original\frame000477.png
# copy ../../dataset/original\frame000478.png
# copy ../../dataset/original\frame000497.png
# copy ../../dataset/original\frame000498.png
# copy ../../dataset/original\frame000499.png
# copy ../../dataset/original\frame000500.png
# copy ../../dataset/original\frame000501.png
# copy ../../dataset/original\frame000502.png
# copy ../../dataset/original\frame000503.png
# copy ../../dataset/original\frame000507.png
# copy ../../dataset/original\frame000508.png
# copy ../../dataset/original\frame000509.png
# copy ../../dataset/original\frame000510.png
# copy ../../dataset/original\frame000511.png
# copy ../../dataset/original\frame000512.png
# copy ../../dataset/original\frame000513.png
# copy ../../dataset/original\frame000514.png
# copy ../../dataset/original\frame000515.png
# copy ../../dataset/original\frame000516.png
# copy ../../dataset/original\frame000517.png
# copy ../../dataset/original\frame000518.png
# copy ../../dataset/original\frame000519.png
# copy ../../dataset/original\frame000520.png
# copy ../../dataset/original\frame000521.png
# copy ../../dataset/original\frame000522.png
# copy ../../dataset/original\frame000523.png
# copy ../../dataset/original\frame000524.png
# copy ../../dataset/original\frame000525.png
# copy ../../dataset/original\frame000526.png
# copy ../../dataset/original\frame000527.png
# copy ../../dataset/original\frame000528.png
# copy ../../dataset/original\frame000529.png
# copy ../../dataset/original\frame000530.png
# copy ../../dataset/original\frame000531.png
# copy ../../dataset/original\frame000532.png
# copy ../../dataset/original\frame000533.png
# copy ../../dataset/original\frame000534.png
# copy ../../dataset/original\frame000535.png
# copy ../../dataset/original\frame000536.png
# copy ../../dataset/original\frame000537.png
# copy ../../dataset/original\frame000538.png
# copy ../../dataset/original\frame000539.png
# copy ../../dataset/original\frame000540.png
# copy ../../dataset/original\frame000541.png
# copy ../../dataset/original\frame000542.png
# copy ../../dataset/original\frame000543.png
# copy ../../dataset/original\frame000544.png
# copy ../../dataset/original\frame000545.png
# copy ../../dataset/original\frame000546.png
# copy ../../dataset/original\frame000547.png
# copy ../../dataset/original\frame000548.png
# copy ../../dataset/original\frame000549.png
# copy ../../dataset/original\frame000550.png
# copy ../../dataset/original\frame000551.png
# copy ../../dataset/original\frame000553.png
# copy ../../dataset/original\frame000554.png
# copy ../../dataset/original\frame000555.png
# copy ../../dataset/original\frame000563.png
# copy ../../dataset/original\frame000564.png
# copy ../../dataset/original\frame000586.png
# copy ../../dataset/original\frame000587.png
# copy ../../dataset/original\frame000589.png
# copy ../../dataset/original\frame000590.png
# copy ../../dataset/original\frame000591.png
# copy ../../dataset/original\frame000592.png
# copy ../../dataset/original\frame000593.png
# copy ../../dataset/original\frame000594.png
# copy ../../dataset/original\frame000597.png
# copy ../../dataset/original\frame000598.png
# copy ../../dataset/original\frame000599.png
# copy ../../dataset/original\frame000600.png
# copy ../../dataset/original\frame000601.png
# copy ../../dataset/original\frame000602.png
# copy ../../dataset/original\frame000603.png
# copy ../../dataset/original\frame000604.png
# copy ../../dataset/original\frame000605.png
# copy ../../dataset/original\frame000606.png
# copy ../../dataset/original\frame000607.png
# copy ../../dataset/original\frame000608.png
# copy ../../dataset/original\frame000609.png
# copy ../../dataset/original\frame000610.png
# copy ../../dataset/original\frame000611.png
# copy ../../dataset/original\frame000612.png
# copy ../../dataset/original\frame000613.png
# copy ../../dataset/original\frame000614.png
# copy ../../dataset/original\frame000615.png
# copy ../../dataset/original\frame000616.png
# copy ../../dataset/original\frame000617.png
# copy ../../dataset/original\frame000618.png
# copy ../../dataset/original\frame000619.png
# copy ../../dataset/original\frame000620.png
# copy ../../dataset/original\frame000621.png
# copy ../../dataset/original\frame000622.png
# copy ../../dataset/original\frame000623.png
# copy ../../dataset/original\frame000627.png
# copy ../../dataset/original\frame000629.png
# copy ../../dataset/original\frame000630.png
# copy ../../dataset/original\frame000631.png
# copy ../../dataset/original\frame000632.png
# copy ../../dataset/original\frame000633.png
# copy ../../dataset/original\frame000634.png
# copy ../../dataset/original\frame000635.png
# copy ../../dataset/original\frame000636.png
# copy ../../dataset/original\frame000637.png
# copy ../../dataset/original\frame000638.png
# copy ../../dataset/original\frame000639.png
# copy ../../dataset/original\frame000640.png
# copy ../../dataset/original\frame000641.png
# copy ../../dataset/original\frame000642.png
# copy ../../dataset/original\frame000643.png
# copy ../../dataset/original\frame000644.png
# copy ../../dataset/original\frame000645.png
# copy ../../dataset/original\frame000646.png
# copy ../../dataset/original\frame000647.png
# copy ../../dataset/original\frame000648.png
# copy ../../dataset/original\frame000649.png
# copy ../../dataset/original\frame000650.png
# copy ../../dataset/original\frame000651.png
# copy ../../dataset/original\frame000652.png
# copy ../../dataset/original\frame000653.png
# copy ../../dataset/original\frame000654.png
# copy ../../dataset/original\frame000655.png
# copy ../../dataset/original\frame000656.png
# copy ../../dataset/original\frame000657.png
# copy ../../dataset/original\frame000658.png
# copy ../../dataset/original\frame000659.png
# copy ../../dataset/original\frame000660.png
# copy ../../dataset/original\frame000661.png
# copy ../../dataset/original\frame000662.png
# copy ../../dataset/original\frame000663.png
# copy ../../dataset/original\frame000664.png
# copy ../../dataset/original\frame000665.png
# copy ../../dataset/original\frame000666.png
# copy ../../dataset/original\frame000667.png
# copy ../../dataset/original\frame000668.png
# copy ../../dataset/original\frame000669.png
# copy ../../dataset/original\frame000670.png
# copy ../../dataset/original\frame000671.png
# copy ../../dataset/original\frame000672.png
# copy ../../dataset/original\frame000673.png
# copy ../../dataset/original\frame000674.png
# copy ../../dataset/original\frame000675.png
# copy ../../dataset/original\frame000676.png
# copy ../../dataset/original\frame000677.png
# copy ../../dataset/original\frame000678.png
# copy ../../dataset/original\frame000679.png
# copy ../../dataset/original\frame000680.png
# copy ../../dataset/original\frame000681.png
# copy ../../dataset/original\frame000682.png
# copy ../../dataset/original\frame000683.png
# copy ../../dataset/original\frame000684.png
# copy ../../dataset/original\frame000685.png
# copy ../../dataset/original\frame000686.png
# copy ../../dataset/original\frame000687.png
# copy ../../dataset/original\frame000688.png
# copy ../../dataset/original\frame000689.png
# copy ../../dataset/original\frame000690.png
# copy ../../dataset/original\frame000691.png
# copy ../../dataset/original\frame000692.png
# copy ../../dataset/original\frame000693.png
# copy ../../dataset/original\frame000694.png
# copy ../../dataset/original\frame000695.png
# copy ../../dataset/original\frame000696.png
# copy ../../dataset/original\frame000697.png
# copy ../../dataset/original\frame000698.png
# copy ../../dataset/original\frame000699.png
# copy ../../dataset/original\frame000700.png
# copy ../../dataset/original\frame000701.png
# copy ../../dataset/original\frame000702.png
# copy ../../dataset/original\frame000703.png
# copy ../../dataset/original\frame000704.png
# copy ../../dataset/original\frame000705.png
# copy ../../dataset/original\frame000706.png
# copy ../../dataset/original\frame000707.png
# copy ../../dataset/original\frame000708.png
# copy ../../dataset/original\frame000709.png
# copy ../../dataset/original\frame000710.png
# copy ../../dataset/original\frame000711.png
# copy ../../dataset/original\frame000712.png
# copy ../../dataset/original\frame000713.png
# copy ../../dataset/original\frame000714.png
# copy ../../dataset/original\frame000715.png
# copy ../../dataset/original\frame000716.png
# copy ../../dataset/original\frame000717.png
# copy ../../dataset/original\frame000718.png
# copy ../../dataset/original\frame000719.png
# copy ../../dataset/original\frame000720.png
# copy ../../dataset/original\frame000721.png
# copy ../../dataset/original\frame000722.png
# copy ../../dataset/original\frame000723.png
# copy ../../dataset/original\frame000724.png
# copy ../../dataset/original\frame000725.png
# copy ../../dataset/original\frame000726.png
# copy ../../dataset/original\frame000727.png
# copy ../../dataset/original\frame000728.png
# Detected 525 blurred images out of 729
# Blurred image ratio : 0.720164609053498
# 0.720164609053498

# %% [markdown]
# ## Check blurry image

# %%
image_generator = paths.list_images(image_path)
first_image = None
for i in range(23):
    first_image = next(image_generator)

# %%
image = cv2.imread(first_image)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
fm = variance_of_laplacian(gray)
text = "Not Blurry"
# if the focus measure is less than the supplied threshold,
# then the image should be considered "blurry"
if fm < threshold:
    print("Blurry")
else:
    print("Sharp")
    
plt.imshow(image)
# Out:
# Blurry

# %% [markdown]
# ## Check sharp images

# %%
for i in range(45):
    first_image = next(image_generator)

# %%
image = cv2.imread(first_image)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
fm = variance_of_laplacian(gray)
text = "Not Blurry"
# if the focus measure is less than the supplied threshold,
# then the image should be considered "blurry"
if fm < threshold:
    print("Blurry")
else:
    print("Sharp")
    
plt.imshow(image)
# Out:
# Blurry

# %%
import random
max_cols = 5

fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(20,20))
for idx in range(20):
    row = idx // max_cols
    col = idx % max_cols

    for j in range()
    image = cv2.imread(next(paths.list_images(dest_blurred)))
    
    axes[row, col].axis("off")
    axes[row, col].imshow(image, cmap="gray", aspect="auto")
plt.subplots_adjust(wspace=.05, hspace=.05)
plt.show()
